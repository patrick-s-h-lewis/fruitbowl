# %% [markdown]
# # USING FRUITBOWL Part 1:  Data collection, corpora and training
# ### First, lets collect some data:
# The cherry framework is designed to collect publication metadata online. The file `scrape_me2.json` contains urls for webpages containing dois. Run cherrymaster.sh to get some data to form a corpus on:

# %%
# %%sh
# cd fruitbowl/cherry/
# sh cherrymaster.sh -p ../../scrape_me2.json
# cd ../..
# Out:
# initialised
# Scraping Run Analysed.
# INFO: Enabled extensions: CoreStats, TelnetConsole, LogStats, CloseSpider, SpiderState
# INFO: Enabled downloader middlewares: HttpAuthMiddleware, DownloadTimeoutMiddleware, UserAgentMiddleware, RetryMiddleware, DefaultHeadersMiddleware, MetaRefreshMiddleware, HttpCompressionMiddleware, RedirectMiddleware, CookiesMiddleware, ChunkedTransferMiddleware, DownloaderStats
# INFO: Enabled spider middlewares: HttpErrorMiddleware, OffsiteMiddleware, RefererMiddleware, UrlLengthMiddleware, DepthMiddleware
# INFO: Enabled item pipelines: CherryPipeline
# INFO: Spider opened
# INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# DEBUG: Telnet console listening on 127.0.0.1:6023
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/people/robert-ryan> (referer: None)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/people/carol-mackintosh> (referer: None)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/> (referer: None)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/people/timothy-newman> (referer: None)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1039/b813394h> (referer: http://www.lifesci.dundee.ac.uk/)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1039/b813394h>
# {'affiliations': '',
#  'authors': u'A Baliani, V Peal, L Gros, R Brun, M Kaiser, MP Barrett, IH Gilbert',
#  'crossref_doi': True,
#  'date': '01 January 2009',
#  'doi': u'10.1039/b813394h',
#  'journal': u'Organic & Biomolecular Chemistry',
#  'publisher': u'Royal Society of Chemistry (RSC)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/',
#  'title': u'Novel functionalized melamine-based nitroheterocycles: synthesis and activity against trypanosomatid parasites'}
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/research-0/publications/cell-and-developmental-biology-2013/cell-and-developmental-biology-2014> (referer: None)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/research-0/publications/gene-regulation-and-expression-2013/gene-regulation-and-expression-2012> (referer: None)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/research-0/publications/cell-and-developmental-biology-2013/cell-and-developmental-biology-0> (referer: None)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/nar/gkt728> (referer: http://www.lifesci.dundee.ac.uk/people/timothy-newman)
# DEBUG: Filtered duplicate request: <GET http://api.crossref.org/works/10.1093/database/bat085> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/research-0/publications/cell-and-developmental-biology-2013/cell-and-developmental-biology-2011> (referer: None)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015> (referer: None)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/nar/gkt728>
# {'affiliations': '',
#  'authors': u'TJ Newman, MA Mamun, CA Nieduszynski, JJ Blow',
#  'crossref_doi': True,
#  'date': '19 August 2013',
#  'doi': u'10.1093/nar/gkt728',
#  'journal': u'Nucleic Acids Research',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/people/timothy-newman',
#  'title': u'Replisome stall events have shaped the distribution of replication origins in the genomes of yeasts'}
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/news/2014/jul/10/2014-tim-hunt-prize-cell-biology-announced> (referer: None)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1073/pnas.1011616107> (referer: http://www.lifesci.dundee.ac.uk/)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1371/journal.pone.0052330> (referer: http://www.lifesci.dundee.ac.uk/)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/research-0/publications/cell-and-developmental-biology-2013/cell-and-developmental-biology> (referer: None)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1158/0008-5472.CAN-07-2092> (referer: http://www.lifesci.dundee.ac.uk/)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1073/pnas.1011616107>
# {'affiliations': '',
#  'authors': u'JS Anderson, MA Ferguson, M Lopez-Larson, D Yurgelun-Todd',
#  'crossref_doi': True,
#  'date': '01 November 2010',
#  'doi': u'10.1073/pnas.1011616107',
#  'journal': u'Proceedings of the National Academy of Sciences',
#  'publisher': u'Proceedings of the National Academy of Sciences',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/',
#  'title': u'Topographic maps of multisensory attention'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1371/journal.pone.0052330>
# {'affiliations': '',
#  'authors': u'A Bragonzi, I Farulla, M Paroni, KB Twomey, L Pirone, NI Lor\xe8, I Bianconi, C Dalmastri, RP Ryan, A Bevivino',
#  'crossref_doi': True,
#  'date': '21 December 2012',
#  'doi': u'10.1371/journal.pone.0052330',
#  'journal': u'PLoS ONE',
#  'publisher': u'Public Library of Science (PLoS)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/',
#  'title': u'Modelling Co-Infection of the Cystic Fibrosis Lung by Pseudomonas aeruginosa and Burkholderia cenocepacia Reveals Influences on Biofilm Formation and Host Response'}
# DEBUG: Redirecting (301) to <GET http://www.lifesci.dundee.ac.uk/technologies> from <GET http://www.lifesci.dundee.ac.uk/cast/light-and-electron-microscopy/staff/dr-graeme-ball>
# DEBUG: Crawled (404) <GET http://api.crossref.org/works/10.1016/j.ydbio.2009.1005.1262|1238> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/cell-and-developmental-biology-2013/cell-and-developmental-biology-0)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1242/jcs.102889> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/gene-regulation-and-expression-2013/gene-regulation-and-expression-2012)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1158/0008-5472.CAN-07-2092>
# {'affiliations': '',
#  'authors': u'M Agostinho, V Santos, F Ferreira, R Costa, J Cardoso, I Pinheiro, J Rino, E Jaffray, RT Hay, J Ferreira',
#  'crossref_doi': True,
#  'date': '01 April 2008',
#  'doi': u'10.1158/0008-5472.can-07-2092',
#  'journal': u'Cancer Research',
#  'publisher': u'American Association for Cancer Research (AACR)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/',
#  'title': u'Conjugation of Human Topoisomerase 2\xa0 with Small Ubiquitin-like Modifiers 2/3 in Response to Topoisomerase Inhibitors: Cell Cycle Stage and Chromosome Domain Specificity'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1038/ncb2495> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/gene-regulation-and-expression-2013/gene-regulation-and-expression-2012)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/database/bat085> (referer: http://www.lifesci.dundee.ac.uk/people/carol-mackintosh)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1016/j.cellsig.2011.08.019> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/gene-regulation-and-expression-2013/gene-regulation-and-expression-2012)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/news/2013/aug/20/discovery-signalling-mechanisms-determining-body-length> (referer: None)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1242/jcs.102889>
# {'affiliations': '',
#  'authors': u'W Zhou, Z Hannoun, E Jaffray, CN Medine, JR Black, S Greenhough, L Zhu, JA Ross, S Forbes, I Wilmut, JP Iredale, RT Hay, DC Hay',
#  'crossref_doi': True,
#  'date': '14 April 2012',
#  'doi': u'10.1242/jcs.102889',
#  'journal': u'Journal of Cell Science',
#  'publisher': u'The Company of Biologists',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/gene-regulation-and-expression-2013/gene-regulation-and-expression-2012',
#  'title': u'SUMOylation of HNF4\xa0 regulates protein stability and hepatocyte function'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1074/mcp.O112.017731> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/gene-regulation-and-expression-2013/gene-regulation-and-expression-2012)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1186/s12859-015-0801-z> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1038/ncb2495>
# {'affiliations': '',
#  'authors': u'LJ Bock, C Pagliuca, N Kobayashi, RA Grove, Y Oku, K Shrestha, C Alfieri, C Golfieri, A Oldani, M Dal Maschio, R Bermejo, TR Hazbun, TU Tanaka, P De Wulf',
#  'crossref_doi': True,
#  'date': '06 May 2012',
#  'doi': u'10.1038/ncb2495',
#  'journal': u'Nature Cell Biology',
#  'publisher': u'Nature Publishing Group',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/gene-regulation-and-expression-2013/gene-regulation-and-expression-2012',
#  'title': u'Cnn1 inhibits the interactions between the KMN complexes of the yeast kinetochore'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1111/pala.12187> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/database/bat085>
# {'affiliations': '',
#  'authors': u'M Tinti, F Madeira, G Murugesan, G Hoxhaj, R Toth, C MacKintosh',
#  'crossref_doi': True,
#  'date': '05 February 2014',
#  'doi': u'10.1093/database/bat085',
#  'journal': u'Database',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/people/carol-mackintosh',
#  'title': u'ANIA: ANnotation and Integrated Analysis of the 14-3-3 interactome'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1016/j.cellsig.2011.08.019>
# {'affiliations': '',
#  'authors': u'A Melvin, S Rocha',
#  'crossref_doi': True,
#  'date': '09 September 2011',
#  'doi': u'10.1016/j.cellsig.2011.08.019',
#  'journal': u'Cellular Signalling',
#  'publisher': u'Elsevier BV',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/gene-regulation-and-expression-2013/gene-regulation-and-expression-2012',
#  'title': u'Chromatin as an oxygen sensor and active player in the hypoxia response'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1074/mcp.O112.017731>
# {'affiliations': '',
#  'authors': u'AI Lamond, M Uhlen, S Horning, A Makarov, CV Robinson, L Serrano, FU Hartl, W Baumeister, AK Werenskiold, JS Andersen, O Vorm, M Linial, R Aebersold, M Mann',
#  'crossref_doi': True,
#  'date': '06 February 2012',
#  'doi': u'10.1074/mcp.o112.017731',
#  'journal': u'Molecular & Cellular Proteomics',
#  'publisher': u'American Society for Biochemistry & Molecular Biology (ASBMB)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/gene-regulation-and-expression-2013/gene-regulation-and-expression-2012',
#  'title': u'Advancing Cell Biology Through Proteomics in Space and Time (PROSPECTS)'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1186/s12859-015-0801-z>
# {'affiliations': '',
#  'authors': u'A Ribeiro, A Golicz, CA Hackett, I Milne, G Stephen, D Marshall, AJ Flavell, M Bayer',
#  'crossref_doi': True,
#  'date': '11 November 2015',
#  'doi': u'10.1186/s12859-015-0801-z',
#  'journal': u'BMC Bioinformatics',
#  'publisher': u'Springer Science + Business Media',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'An investigation of causes of false positive single nucleotide polymorphisms using simulated reads from a small eukaryote genome'}
# DEBUG: Crawled (404) <GET http://api.crossref.org/works/10.371/journal.pone.0015264> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/cell-and-developmental-biology-2013/cell-and-developmental-biology)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/nar/gkv805> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1111/pala.12187>
# {'affiliations': u'Division of Plant Sciences; University of Dundee at the James Hutton Institute; Invergowrie Dundee DD2 5DA UK; School of Plant Biology; University of Western Australia; Crawley WA 6009 Australia; School of Earth and Ocean Sciences; Cardiff University; Main Building Park Place Cardiff CF10 3AT UK',
#  'authors': u'D Edwards, L Cherns, JA Raven',
#  'crossref_doi': True,
#  'date': '18 August 2015',
#  'doi': u'10.1111/pala.12187',
#  'journal': u'Palaeontology',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Could land-based early photosynthesizing ecosystems have bioengineered the planet in mid-Palaeozoic times?'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/jxb/erv053> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1186/s13059-015-0582-8> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/events/2014/feb/6/chromosome-segregation-meiosis-i-mouse-oocytes> (referer: None)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1111/nph.13545> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/nar/gkv805>
# {'affiliations': '',
#  'authors': u'GB Motion, A Howden, E Huitema, S Jones',
#  'crossref_doi': True,
#  'date': '24 August 2015',
#  'doi': u'10.1093/nar/gkv805',
#  'journal': u'Nucleic Acids Res',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'DNA-binding protein prediction using plant specific support vector machines: validation and application of a new genome annotation tool'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1111/mec.13434> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (404) <GET http://api.crossref.org/works/10.1016/j.ydbio.2009.1005.1262|1238/agency> (referer: http://api.crossref.org/works/10.1016/j.ydbio.2009.1005.1262|1238)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/jxb/erv053>
# {'affiliations': '',
#  'authors': u'CH Hurst, PA Hemsley',
#  'crossref_doi': True,
#  'date': '27 February 2015',
#  'doi': u'10.1093/jxb/erv053',
#  'journal': u'Journal of Experimental Botany',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Current perspective on protein S-acylation in plants: more than just a fatty anchor?'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1186/s13059-015-0582-8>
# {'affiliations': '',
#  'authors': u'JA Chapman, M Mascher, A Bulu\xe7, K Barry, E Georganas, A Session, V Strnadova, J Jenkins, S Sehgal, L Oliker, J Schmutz, KA Yelick, U Scholz, R Waugh, JA Poland, GJ Muehlbauer, N Stein, DS Rokhsar',
#  'crossref_doi': True,
#  'date': '30 January 2015',
#  'doi': u'10.1186/s13059-015-0582-8',
#  'journal': u'Genome Biol',
#  'publisher': u'Springer Science + Business Media',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'A whole-genome shotgun approach for assembling and anchoring the hexaploid bread wheat genome'}
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/events/2013/sep/6/%E2%80%9Cdesign-and-selection-glycosidase-inhibitors-towards-therapies-diabetes-and> (referer: None)
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/events/2013/sep/6/%E2%80%9Cexpanding-central-dogma%E2%80%9D> (referer: None)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1111/nph.13545>
# {'affiliations': u'Cell and Molecular Sciences; The James Hutton Institute; Invergowrie Dundee DD2 5DA UK; Catalan Institution of Research and Advanced Studies (ICREA); 08010 Barcelona Spain; Computer Science Department; 1422 Computer Science; Stony Brook University; Stony Brook NY 11794-4400 USA; Computational Genomics; Universitat Pompeu Fabra; 08002 Barcelona Spain; Informatics and Computational Sciences; The James Hutton Institute; Invergowrie Dundee DD2 5DA UK; Plant Sciences Division; College of Life Sciences; University of Dundee; Invergowrie Dundee DD2 5DA UK; Max F. Perutz Laboratories; Medical University of Vienna; Dr Bohrgasse 9/3 1030 Vienna Austria; Institute of Molecular, Cell and Systems Biology; College of Medical, Veterinary and Life Sciences; University of Glasgow; Glasgow G12 8QQ UK; Department of Applied Genetics and Cell Biology; University of Natural Resources and Life Sciences; Muthgasse 18 1190 Vienna Austria',
#  'authors': u'R Zhang, CPG Calixto, NA Tzioutziou, AB James, CG Simpson, W Guo, Y Marquez, M Kalyna, R Patro, E Eyras, A Barta, HG Nimmo, JWS Brown',
#  'crossref_doi': True,
#  'date': '25 June 2015',
#  'doi': u'10.1111/nph.13545',
#  'journal': u'New Phytologist',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u' AtRTD - a comprehensive reference transcript dataset resource for\xa0accurate quantification of transcript-specific expression in Arabidopsis thaliana '}
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/events/2013/sep/6/two-photon-imaging-mucosal-barrier-function-and-luminal-antigen-acquisition> (referer: None)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1111/mec.13434>
# {'affiliations': u'Centre for Plant Sciences; University of Leeds; Leeds LS2 9JT UK; Science and Advice for Scottish Agriculture; Edinburgh EH12 9FJ UK; Information and Computational Sciences Group; Dundee Effector Consortium; The James Hutton Institute; Invergowrie Dundee DD2 5DA UK; Institute of Evolutionary Biology; University of Edinburgh; Edinburgh EH8 9YL UK; Division of Plant Sciences; College of Life Sciences; University of Dundee; Dundee DD1 5EH UK; School of Biology; University of St Andrews; North Haugh St Andrews KY16 9TZ UK; Scottish Agronomy Ltd; Arlary Farm Milnathort Kinross KY13 9SJ UK; Cell and Molecular Sciences Group; Dundee Effector Consortium; The James Hutton Institute; Invergowrie Dundee DD2 5DA UK',
#  'authors': u'S Eves-van den Akker, CJ Lilley, A Reid, J Pickup, E Anderson, PJ Cock, M Blaxter, PE Urwin, JT Jones, VC Blok',
#  'crossref_doi': True,
#  'date': '26 November 2015',
#  'doi': u'10.1111/mec.13434',
#  'journal': u'Molecular Ecology',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'A metagenetic approach to determine the diversity and distribution of cyst nematodes at the level of the country, the field and the individual'}
# DEBUG: Scraped from <404 http://api.crossref.org/works/10.1016/j.ydbio.2009.1005.1262|1238/agency>
# {'doi': u'10.1016/j.ydbio.2009.1005.1262|1238',
#  'error': {'broken_doi': u'10.1016/j.ydbio.2009.1005.1262|1238'},
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/cell-and-developmental-biology-2013/cell-and-developmental-biology-0'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/jxb/erv451> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1371/journal.pbio.1001415> (referer: http://www.lifesci.dundee.ac.uk/news/2013/aug/20/discovery-signalling-mechanisms-determining-body-length)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1371/journal.ppat.1004918> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1016/j.chom.2015.01.011> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1104/pp.15.01169> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1105/tpc.15.00572> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/jxb/erv451>
# {'affiliations': '',
#  'authors': u'JA Raven, J Beardall',
#  'crossref_doi': True,
#  'date': '14 October 2015',
#  'doi': u'10.1093/jxb/erv451',
#  'journal': u'EXBOTJ',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u' The ins and outs of CO 2 '}
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/people/arno-muller> (referer: None)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1371/journal.pbio.1001415>
# {'affiliations': '',
#  'authors': u'I Olivera-Martinez, H Harada, PA Halley, KG Storey',
#  'crossref_doi': True,
#  'date': '30 October 2012',
#  'doi': u'10.1371/journal.pbio.1001415',
#  'journal': u'PLoS Biology',
#  'publisher': u'Public Library of Science (PLoS)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/news/2013/aug/20/discovery-signalling-mechanisms-determining-body-length',
#  'title': u'Loss of FGF-Dependent Mesoderm Identity and Rise of Endogenous Retinoid Signalling Determine Cessation of Body Axis Elongation'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1371/journal.ppat.1004918>
# {'affiliations': '',
#  'authors': u'M Jaouannet, JA Morris, PE Hedley, JIB Bos',
#  'crossref_doi': True,
#  'date': '20 May 2015',
#  'doi': u'10.1371/journal.ppat.1004918',
#  'journal': u'PLoS Pathog',
#  'publisher': u'Public Library of Science (PLoS)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Characterization of Arabidopsis Transcriptional Responses to Different Aphid Species Reveals Genes that Contribute to Host Susceptibility and Non-host Resistance'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1016/j.chom.2015.01.011>
# {'affiliations': '',
#  'authors': u'D Bulgarelli, R Garrido-Oter, P M\xfcnch, A Weiman, J Dr\xf6ge, Y Pan, A McHardy, P Schulze-Lefert',
#  'crossref_doi': True,
#  'date': '26 February 2015',
#  'doi': u'10.1016/j.chom.2015.01.011',
#  'journal': u'Cell Host & Microbe',
#  'publisher': u'Elsevier BV',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Structure and Function of the Bacterial Root Microbiota in Wild and Domesticated Barley'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/plankt/fbv036> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1104/pp.15.01169>
# {'affiliations': '',
#  'authors': u'Y Du, MH Mpina, PRJ Birch, K Bouwmeester, F Govers',
#  'crossref_doi': True,
#  'date': '02 September 2015',
#  'doi': u'10.1104/pp.15.01169',
#  'journal': u'Plant Physiology',
#  'publisher': u'American Society of Plant Biologists (ASPB)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Phytophthora infestans RXLR effector AVR1 interacts with exocyst component Sec5 to manipulate plant immunity'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1105/tpc.15.00572>
# {'affiliations': '',
#  'authors': u'JW Brown, CG Simpson, Y Marquez, GM Gadd, A Barta, M Kalyna',
#  'crossref_doi': True,
#  'date': '01 August 2015',
#  'doi': u'10.1105/tpc.15.00572',
#  'journal': u'The Plant Cell',
#  'publisher': u'American Society of Plant Biologists (ASPB)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Lost in Translation: Pitfalls in Deciphering Plant Alternative Splicing Transcripts'}
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/people/graeme-ball> (referer: None)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1371/journal.pone.0144674> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/plankt/fbv036>
# {'affiliations': '',
#  'authors': u'KJ Flynn, M St John, JA Raven, DO Skibinski, JI Allen, A Mitra, EE Hofmann',
#  'crossref_doi': True,
#  'date': '19 May 2015',
#  'doi': u'10.1093/plankt/fbv036',
#  'journal': u'Journal of Plankton Research',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Acclimation, adaptation, traits and trade-offs in plankton functional type models: reconciling terminology for biology and modelling'}
# DEBUG: Retrying <GET http://api.crossref.org/works/10.371/journal.pone.0015264/agency> (failed 1 times): 500 Internal Server Error
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/bfgp/elv013> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1016/j.celrep.2012.10.002> (referer: http://www.lifesci.dundee.ac.uk/events/2014/feb/6/chromosome-segregation-meiosis-i-mouse-oocytes)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1016/j.cub.2013.02.004> (referer: http://www.lifesci.dundee.ac.uk/events/2014/feb/6/chromosome-segregation-meiosis-i-mouse-oocytes)
# DEBUG: Crawled (404) <GET http://api.crossref.org/works/10.1242/dev.061317.> (referer: http://www.lifesci.dundee.ac.uk/events/2014/feb/6/chromosome-segregation-meiosis-i-mouse-oocytes)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1371/journal.pone.0144674>
# {'affiliations': '',
#  'authors': u'P Vieira, S Eves-van den Akker, R Verma, S Wantoch, JD Eisenback, K Kamo',
#  'crossref_doi': True,
#  'date': '14 December 2015',
#  'doi': u'10.1371/journal.pone.0144674',
#  'journal': u'PLOS ONE',
#  'publisher': u'Public Library of Science (PLoS)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'The Pratylenchus penetrans Transcriptome as a Source for the Development of Alternative Control Strategies: Mining for Putative Genes Involved in Parasitism and Evaluation of in planta RNAi'}
# DEBUG: Crawled (200) <GET http://www.lifesci.dundee.ac.uk/technologies> (referer: None)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/bfgp/elv013>
# {'affiliations': '',
#  'authors': u'GB Motion, TM Amaro, N Kulagina, E Huitema',
#  'crossref_doi': True,
#  'date': '06 April 2015',
#  'doi': u'10.1093/bfgp/elv013',
#  'journal': u'Briefings in Functional Genomics',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Nuclear processes associated with plant immunity and pathogen susceptibility'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1016/j.celrep.2012.10.002>
# {'affiliations': '',
#  'authors': u'S Touati, D Cladi\xe8re, L Lister, I Leontiou, J Chambon, A Rattani, F B\xf6ttger, O Stemmann, K Nasmyth, M Herbert, K Wassmann',
#  'crossref_doi': True,
#  'date': '01 November 2012',
#  'doi': u'10.1016/j.celrep.2012.10.002',
#  'journal': u'Cell Reports',
#  'publisher': u'Elsevier BV',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/events/2014/feb/6/chromosome-segregation-meiosis-i-mouse-oocytes',
#  'title': u'Cyclin A2 Is Required for Sister Chromatid Segregation, But Not Separase Control, in Mouse Oocyte Meiosis'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1016/j.cub.2013.02.004>
# {'affiliations': '',
#  'authors': u'J Chambon, S Touati, S Berneau, D Cladi\xe8re, C Hebras, R Groeme, A McDougall, K Wassmann',
#  'crossref_doi': True,
#  'date': '21 February 2013',
#  'doi': u'10.1016/j.cub.2013.02.004',
#  'journal': u'Current Biology',
#  'publisher': u'Elsevier BV',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/events/2014/feb/6/chromosome-segregation-meiosis-i-mouse-oocytes',
#  'title': u'The PP2A Inhibitor I2PP2A Is Essential for Sister Chromatid Segregation in Oocyte Meiosis II'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1016/j.molp.2015.04.012> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1111/nph.13548> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (404) <GET http://api.crossref.org/works/10.1126/science.1200752%3Cdiv> (referer: http://www.lifesci.dundee.ac.uk/events/2013/sep/6/%E2%80%9Cexpanding-central-dogma%E2%80%9D)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1002/9781118958841.ch7> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1016/j.molp.2015.04.012>
# {'affiliations': '',
#  'authors': u'X Wang, P Boevink, H McLellan, M Armstrong, T Bukharova, Z Qin, P Birch',
#  'crossref_doi': True,
#  'date': '02 May 2015',
#  'doi': u'10.1016/j.molp.2015.04.012',
#  'journal': u'Molecular Plant',
#  'publisher': u'Elsevier BV',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'A Host KH RNA-Binding Protein Is a Susceptibility Factor Targeted by an RXLR Effector to Promote Late Blight Disease'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1371/journal.pone.0132787> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (404) <GET http://api.crossref.org/works/10.1038/%3Cspan> (referer: http://www.lifesci.dundee.ac.uk/events/2013/sep/6/%E2%80%9Cexpanding-central-dogma%E2%80%9D)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1126/science.1232552> (referer: http://www.lifesci.dundee.ac.uk/events/2013/sep/6/%E2%80%9Cdesign-and-selection-glycosidase-inhibitors-towards-therapies-diabetes-and)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1111/nph.13548>
# {'affiliations': u'Institute of Biological Environmental and Rural Sciences (IBERS); Aberystwyth, University; Aberystwyth SY23 3DA UK; Division of Plant Sciences; University of Dundee at The James Hutton Institute; Invergowrie Dundee DD2 5DA UK; Cell and Molecular Sciences; The James Hutton Institute (JHI); Invergowrie Dundee DD2 5DA UK; Information and Computational Sciences; The James Hutton Institute (JHI); Invergowrie Dundee DD2 5DA UK',
#  'authors': u'D Phillips, G Jenkins, M Macaulay, C Nibau, J Wnetrzak, D Fallding, I Colas, H Oakey, R Waugh, L Ramsay',
#  'crossref_doi': True,
#  'date': '07 August 2015',
#  'doi': u'10.1111/nph.13548',
#  'journal': u'New Phytologist',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'The effect of temperature on the male and female recombination landscape of barley'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1186/s13059-015-0704-3> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1002/9781118958841.ch7>
# {'affiliations': '',
#  'authors': u'JA Raven',
#  'crossref_doi': True,
#  'date': '14 April 2015',
#  'doi': u'10.1002/9781118958841.ch7',
#  'journal': u'Phosphorus Metabolism in Plants',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Interactions between Nitrogen and Phosphorus metabolism'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1371/journal.pone.0132787>
# {'affiliations': '',
#  'authors': u'I Marcotuli, K Houston, R Waugh, GB Fincher, RA Burton, A Blanco, A Gadaleta',
#  'crossref_doi': True,
#  'date': '15 July 2015',
#  'doi': u'10.1371/journal.pone.0132787',
#  'journal': u'PLOS ONE',
#  'publisher': u'Public Library of Science (PLoS)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Genome Wide Association Mapping for Arabinoxylan Content in a Collection of Tetraploid Wheats'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1126/science.1232552>
# {'affiliations': '',
#  'authors': u'J Kim, R Resende, T Wennekes, H Chen, N Bance, S Buchini, AG Watts, P Pilling, VA Streltsov, M Petric, R Liggins, S Barrett, JL McKimm-Breschkin, M Niikura, SG Withers',
#  'crossref_doi': True,
#  'date': '21 February 2013',
#  'doi': u'10.1126/science.1232552',
#  'journal': u'Science',
#  'publisher': u'American Association for the Advancement of Science (AAAS)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/events/2013/sep/6/%E2%80%9Cdesign-and-selection-glycosidase-inhibitors-towards-therapies-diabetes-and',
#  'title': u'Mechanism-Based Covalent Neuraminidase Inhibitors with Broad-Spectrum Influenza Antiviral Activity'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1186/s13059-015-0704-3>
# {'affiliations': '',
#  'authors': u'D Staiger, GG Simpson',
#  'crossref_doi': True,
#  'date': '06 July 2015',
#  'doi': u'10.1186/s13059-015-0704-3',
#  'journal': u'Genome Biol',
#  'publisher': u'Springer Science + Business Media',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Enter exitrons'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1111/nph.13171> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1111/mpp.12280> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/jxb/erv009> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1111/nph.13171>
# {'affiliations': u'Division of Plant Sciences; University of Dundee at the James Hutton Institute; Errol Road Invergowrie Dundee DD2 5DA UK; Ecological Sciences; James Hutton Institute; Errol Road Invergowrie Dundee DD2 5DA UK',
#  'authors': u'AE Bennett, D Grussu, J Kam, S Caul, C Halpin',
#  'crossref_doi': True,
#  'date': '12 November 2014',
#  'doi': u'10.1111/nph.13171',
#  'journal': u'New Phytologist',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Plant lignin content altered by soil microbial community'}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1111/nph.13266> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/jxb/erv298> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (404) <GET http://api.crossref.org/works/10.1038/nature12868.> (referer: http://www.lifesci.dundee.ac.uk/people/graeme-ball)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/bioinformatics/btv425> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1111/pce.12567> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1111/mpp.12280>
# {'affiliations': u'Biology Department; University of Gent; KL Ledeganckstraat 35 B9000 Gent Belgium; College of Life Sciences; University of Dundee; Dundee DD1 5EH UK; NemaLab/ICAAM-Instituto de Ci\xeancias Agr\xe1rias e Ambientais Mediterr\xe2nicas; Universidade de \xc9vora; N\xfacleo da Mitra, Ap. 94 7002-554 \xc9vora Portugal; School of Biology; University of St Andrews; North Haugh St Andrews KY16 9TZ UK; Cell and Molecular Sciences Group/Information and Computer Sciences Group (PJAC); The James Hutton Institute; Invergowrie Dundee DD2 5DA UK',
#  'authors': u'M Espada, AC Silva, S Eves van den Akker, PJA Cock, M Mota, JT Jones',
#  'crossref_doi': True,
#  'date': '18 May 2015',
#  'doi': u'10.1111/mpp.12280',
#  'journal': u'Molecular Plant Pathology',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u' Identification and characterization of parasitism genes from the pinewood nematode Bursaphelenchus xylophilus reveals a multilayered detoxification strategy '}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/jxb/erv009>
# {'affiliations': '',
#  'authors': u'JA Raven, H Griffiths',
#  'crossref_doi': True,
#  'date': '20 February 2015',
#  'doi': u'10.1093/jxb/erv009',
#  'journal': u'Journal of Experimental Botany',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Photosynthesis in reproductive structures: costs and benefits'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1111/nph.13266>
# {'affiliations': u'Cell and Molecular Sciences; James Hutton Institute (JHI); Invergowrie Dundee DD2 5DA UK; Division of Plant Sciences; College of Life Sciences; University of Dundee at JHI; Invergowrie Dundee DD2 5DA UK; Department of Plant Pathology; University of Minnesota; St Paul MN 55108 USA; CGIAR Consortium Office; Montpellier Cedex 5 France',
#  'authors': u'IK Dawson, J Russell, W Powell, B Steffenson, WTB Thomas, R Waugh',
#  'crossref_doi': True,
#  'date': '21 January 2015',
#  'doi': u'10.1111/nph.13266',
#  'journal': u'New Phytologist',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Barley: a translational model for adaptation to climate change'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/jxb/erv298>
# {'affiliations': '',
#  'authors': u'JA Raven',
#  'crossref_doi': True,
#  'date': '15 June 2015',
#  'doi': u'10.1093/jxb/erv298',
#  'journal': u'EXBOTJ',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Implications of mutation of organelle genomes for organelle function and evolution'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/bioinformatics/btv425>
# {'affiliations': '',
#  'authors': u'M Gierli\u0144ski, C Cole, P Schofield, NJ Schurch, A Sherstnev, V Singh, N Wrobel, K Gharbi, G Simpson, T Owen-Hughes, M Blaxter, GJ Barton',
#  'crossref_doi': True,
#  'date': '23 July 2015',
#  'doi': u'10.1093/bioinformatics/btv425',
#  'journal': u'Bioinformatics',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Statistical models for RNA-seq data derived from a two-condition 48-replicate experiment'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1111/pce.12567>
# {'affiliations': u'Univ Dundee, James Hutton Inst, Div Plant Sci; Dundee DD2 5DA Scotland',
#  'authors': u'JA RAVEN',
#  'crossref_doi': True,
#  'date': '20 May 2015',
#  'doi': u'10.1111/pce.12567',
#  'journal': u'Plant, Cell & Environment',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u' Harry Smith, FRS: co-founding editor and first Chief Editor of Plant, Cell & Environment '}
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1007/s10811-014-0323-5> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/femsec/fiu024> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1093/jxb/erv128> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1111/jpy.12287> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1094/PHYTO-01-15-0005-FI> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1104/pp.114.252882> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1016/j.pbi.2015.05.015> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (404) <GET http://api.crossref.org/works/10.1242/dev.061317./agency> (referer: http://api.crossref.org/works/10.1242/dev.061317.)
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1007/s10811-014-0323-5>
# {'affiliations': '',
#  'authors': u'JA Raven, PJ Ralph',
#  'crossref_doi': True,
#  'date': '09 June 2014',
#  'doi': u'10.1007/s10811-014-0323-5',
#  'journal': u'J Appl Phycol',
#  'publisher': u'Springer Science + Business Media',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Enhanced biofuel production using optimality, pathway modification and waste minimization'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/femsec/fiu024>
# {'affiliations': '',
#  'authors': u'B Lemaire, O Dlodlo, S Chimphango, C Stirton, B Schrire, JS Boatwright, O Honnay, E Smets, J Sprent, EK James, AM Muasya',
#  'crossref_doi': True,
#  'date': '08 December 2014',
#  'doi': u'10.1093/femsec/fiu024',
#  'journal': u'FEMS Microbiology Ecology',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Symbiotic diversity, specificity and distribution of rhizobia in native legumes of the Core Cape Subregion (South Africa)'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1093/jxb/erv128>
# {'affiliations': '',
#  'authors': u'Q He, H McLellan, PC Boevink, A Sadanandom, C Xie, PRJ Birch, Z Tian',
#  'crossref_doi': True,
#  'date': '06 April 2015',
#  'doi': u'10.1093/jxb/erv128',
#  'journal': u'Journal of Experimental Botany',
#  'publisher': u'Oxford University Press (OUP)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'U-box E3 ubiquitin ligase PUB17 acts in the nucleus to promote specific immune pathways triggered by Phytophthora infestans'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1111/jpy.12287>
# {'affiliations': u'Functional Plant Biology and Climate Change Cluster; University of Technology Sydney; Ultimo NSW 2007 Australia; Division of Plant Science; University of Dundee at the James Hutton Institute; Invergowrie Dundee DD2 5DA UK',
#  'authors': u'JA Raven',
#  'crossref_doi': True,
#  'date': '01 April 2015',
#  'doi': u'10.1111/jpy.12287',
#  'journal': u'Journal of Phycology',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'Compartmentation of defensive compound synthesis in a red alga'}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1094/PHYTO-01-15-0005-FI>
# {'affiliations': '',
#  'authors': u'WE Fry, PRJ Birch, HS Judelson, NJ Gr\xfcnwald, G Danies, KL Everts, AJ Gevens, BK Gugino, DA Johnson, SB Johnson, MT McGrath, KL Myers, JB Ristaino, PD Roberts, G Secor, CD Smart',
#  'crossref_doi': True,
#  'date': '11 March 2015',
#  'doi': u'10.1094/phyto-01-15-0005-fi',
#  'journal': u'Phytopathology',
#  'publisher': u'Scientific Societies',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u' Five Reasons to Consider Phytophthora infestans a Reemerging Pathogen '}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1104/pp.114.252882>
# {'affiliations': '',
#  'authors': u'E Tavakol, R Okagaki, G Verderio, V Shariati J., A Hussien, H Bilgic, MJ Scanlon, NR Todt, TJ Close, A Druka, R Waugh, B Steuernagel, R Ariyadasa, A Himmelbach, N Stein, GJ Muehlbauer, L Rossini',
#  'crossref_doi': True,
#  'date': '27 March 2015',
#  'doi': u'10.1104/pp.114.252882',
#  'journal': u'Plant Physiology',
#  'publisher': u'American Society of Plant Biologists (ASPB)',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u' The Barley Uniculme4 Gene Encodes a BLADE-ON-PETIOLE-Like Protein That Controls Tillering and Leaf Patterning '}
# DEBUG: Scraped from <200 http://api.crossref.org/works/10.1016/j.pbi.2015.05.015>
# {'affiliations': '',
#  'authors': u'RG Fray, GG Simpson',
#  'crossref_doi': True,
#  'date': '03 June 2015',
#  'doi': u'10.1016/j.pbi.2015.05.015',
#  'journal': u'Current Opinion in Plant Biology',
#  'publisher': u'Elsevier BV',
#  'source_url': 'http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015',
#  'title': u'The Arabidopsis epitranscriptome'}
# DEBUG: Scraped from <404 http://api.crossref.org/works/10.1242/dev.061317./agency>
# {'doi': u'10.1242/dev.061317.',
#  'error': {'broken_doi': u'10.1242/dev.061317.'},
#  'source_url': 'http://www.lifesci.dundee.ac.uk/events/2014/feb/6/chromosome-segregation-meiosis-i-mouse-oocytes'}
# DEBUG: Crawled (404) <GET http://api.crossref.org/works/10.1038/%3Cspan/agency> (referer: http://api.crossref.org/works/10.1038/%3Cspan)
# DEBUG: Crawled (404) <GET http://api.crossref.org/works/10.1126/science.1200752%3Cdiv/agency> (referer: http://api.crossref.org/works/10.1126/science.1200752%3Cdiv)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1017/S147355041400041x> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1371/journal.pone.0130890> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1104/pp.15.00140> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1007/s00239-015-9665-0> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Crawled (200) <GET http://api.crossref.org/works/10.1038/srep15229> (referer: http://www.lifesci.dundee.ac.uk/research-0/publications/plant-sciences-2013/plant-sciences-2015)
# DEBUG: Scraped from <404 http://api.crossref.org/works/10.1038/%3Cspan/agency>
# {'doi': u'10.1038/<span',
#  'error': {'broken_doi': u'10.1038/<span'},
#  'source_url': 'http://www.lifesci.dundee.ac.uk/events/2013/sep/6/%E2%80%9Cexpanding-central-dogma%E2%80%9D'}
# DEBUG: Scraped from <404 http://api.crossref.org/works/10.1126/science.1200752%3Cdiv/agency>
# {'doi': u'10.1126/science.1200752<div',
#  'error': {'broken_doi': u'10.1126/science.1200752<div'},
# ...
#                   u'Department of Biochemistry, University of Cambridge, 80 Tennis Court Road, Cambridge, CB2 1GA (UK)'],
#  'authors': u'A Ciulli, DE Scott, M Ando, F Reyes, SA Saldanha, KL Tuck, DY Chirgadze, TL Blundell, C Abell',
#  'date': u'26 September 2008',
#  'doi': u'10.1002/cbic.200800437',
#  'journal': u'ChemBioChem',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications',
#  'title': u' Inhibition of Mycobacterium tuberculosis Pantothenate Synthetase by Analogues of the Reaction Intermediate '}
# DEBUG: Redirecting (301) to <GET http://www.pnas.org/lookup/doi/10.1073/pnas.1304045110> from <GET http://www.pnas.org/cgi/doi/10.1073/pnas.1304045110>
# DEBUG: Redirecting (302) to <GET http://onlinelibrary.wiley.com/doi/10.1002/anie.201202544/abstract> from <GET http://onlinelibrary.wiley.com/resolve/doi?DOI=10.1002/anie.201202544>
# DEBUG: Redirecting (301) to <GET http://jb.asm.org/lookup/doi/10.1128/JB.187.15.5061-5066.2005> from <GET http://jb.asm.org/cgi/doi/10.1128/JB.187.15.5061-5066.2005>
# DEBUG: Redirecting (301) to <GET http://www.nature.com/nmeth/journal/v8/n10/full/nmeth.1679.html> from <GET http://www.nature.com/doifinder/10.1038/nmeth.1679>
# DEBUG: Crawled (200) <GET http://www.sciencedirect.com/science/article/pii/S1074552112003249> (referer: None)
# DEBUG: Scraped from <200 http://www.sciencedirect.com/science/article/pii/S1074552112003249>
# {'abstract': u'SummaryFragment screening is widely used to identify attractive starting points for drug design. However, its potential and limitations to assess the tractability of often challenging protein:protein interfaces have been underexplored. Here, we address this question by means of a systematic deconstruction of lead-like inhibitors of the pVHL:HIF-1\u03b1 interaction into their component fragments. Using biophysical techniques commonly employed for screening, we could only detect binding of fragments that violate the Rule of Three, are more complex than those typically screened against classical druggable targets, and occupy two adjacent binding subsites at the interface rather than just one. Analyses based on ligand and group lipophilicity efficiency of anchored fragments were applied to dissect the individual subsites and probe for binding hot spots. The implications of our findings for targeting protein interfaces by fragment-based approaches are discussed.',
#  'affiliations': [u'Department of Chemistry, University of Cambridge, Cambridge, CB2 1EW, UK',
#                   u'Department of Molecular, Cellular and Developmental Biology, Yale University, New Haven, CT 06511, USA',
#                   u'Department of Pharmacology, Yale University, New Haven, CT 06511, USA',
#                   u'Department of Chemistry, Yale University, New Haven, CT 06511, USA'],
#  'authors': u'I Van\xa0Molle, A Thomann, D Buckley, E So, S Lang, C Crews, A Ciulli',
#  'date': u'01 October 2012',
#  'doi': u'10.1016/j.chembiol.2012.08.015',
#  'journal': u'Chemistry & Biology',
#  'publisher': u'Elsevier BV',
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications',
#  'title': u'Dissecting Fragment-Based Lead Discovery at the von Hippel-Lindau Protein:Hypoxia Inducible Factor 1\u03b1 Protein-Protein Interface'}
# DEBUG: Redirecting (302) to <GET http://www.pnas.org/content/110/32/12984> from <GET http://www.pnas.org/lookup/doi/10.1073/pnas.1304045110>
# DEBUG: Crawled (200) <GET http://www.jbc.org/content/290/7/4178> (referer: None)
# DEBUG: Crawled (200) <GET http://pubs.acs.org/doi/abs/10.1021/bi0502036> (referer: None) ['partial']
# DEBUG: Crawled (200) <GET http://onlinelibrary.wiley.com/doi/10.1002/anie.201206231/abstract> (referer: None)
# DEBUG: Redirecting (302) to <GET http://jb.asm.org/content/187/15/5061> from <GET http://jb.asm.org/lookup/doi/10.1128/JB.187.15.5061-5066.2005>
# DEBUG: Scraped from <200 http://www.jbc.org/content/290/7/4178>
# {'doi': u'10.1074/jbc.m114.616664',
#  'error': {'missing_pub': 'www.jbc.org'},
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications'}
# DEBUG: Scraped from <200 http://pubs.acs.org/doi/abs/10.1021/bi0502036>
# {'abstract': u' The NADPH-dependent reduction of ketopantoate to pantoate, catalyzed by ketopantoate reductase (KPR; EC 1.1.1.169), is essential for the biosynthesis of pantothenate (vitamin B5). Here we present the crystal structure of Escherichia coli KPR with NADP+ bound, solved to 2.1 \xc5 resolution. The cofactor is bound in the active site cleft between the N-terminal Rossmann-fold domain and the C-terminal \u03b1-helical domain. The thermodynamics of cofactor and substrate binding were characterized by isothermal titration calorimetry. The dissociation constant for NADP+ was found to be 6.5 \u03bcM, 20-fold larger than that for NADPH (0.34 \u03bcM). The difference is primarily due to the entropic term, suggesting favorable hydrophobic interactions of the more lipophilic nicotinamide ring in NADPH. Comparison of this binary complex structure with the previously studied apoenzyme reveals no evidence for large domain movements on cofactor binding. This observation is further supported both by molecular dynamics and by calorimetric analysis. A model of the ternary complex, based on the structure presented here, provides novel insights into the molecular mechanism of enzyme catalysis. We propose a conformational switch of the essential Lys176 from the \u201cresting\u201d state observed in our structure to an \u201cactive\u201d state, to bind ketopantoate. Additionally, we identify the importance of Asn98 for substrate binding and enzyme catalysis.  ',
#  'affiliations': [u'Department of Biochemistry, University of Cambridge, 80 Tennis Court Road, Cambridge CB2 1GA, U.K., University Chemical Laboratory, Lensfield Road, Cambridge CB2 1EW, U.K., Department of Plant Sciences, University of Cambridge, Downing Street, Cambridge CB2 3EA, U.K., and Astex Technology Ltd., 436 Cambridge Science Park, Milton Road, Cambridge CB4 0QA, U.K. '],
#  'authors': u'CMC Lobley, A Ciulli, HM Whitney, G Williams, AG Smith, C Abell, TL Blundell',
#  'date': u'01 June 2005',
#  'doi': u'10.1021/bi0502036',
#  'journal': u'Biochemistry',
#  'publisher': u'American Chemical Society (ACS)',
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications',
#  'title': u' The Crystal Structure of Escherichia coli Ketopantoate Reductase with NADP + Bound \u2020 , \u2021 '}
# DEBUG: Scraped from <200 http://onlinelibrary.wiley.com/doi/10.1002/anie.201206231/abstract>
# {'abstract': u'By design: Novel small-molecule inhibitors of the interaction between the von\u2009Hippel\u2013Lindau ligase (VHL) and its molecular target HIF1\u03b1, a transcription factor involved in oxygen sensing, have been developed and studied. The most potent inhibitor binds with an IC50 value of 0.9\u2005\u03bcM and is thus the first sub-micromolar inhibitor of the VHL\u2013HIF1\u03b1 interaction.',
#  'affiliations': [u'Departments of Chemistry, Molecular, Cellular & Developmental Biology and Pharmacology and Center for Molecular Discovery, Yale University, New Haven, CT 06511 (USA)',
#                   u'Department of Chemistry, University of Cambridge, Lensfield Road, Cambridge CB2 1EW (UK)'],
#  'authors': u'DL Buckley, JL Gustafson, I Van Molle, AG Roth, HS Tae, PC Gareiss, WL Jorgensen, A Ciulli, CM Crews',
#  'date': u'12 October 2012',
#  'doi': u'10.1002/anie.201206231',
#  'journal': u'Angewandte Chemie International Edition',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications',
#  'title': u'Small-Molecule Inhibitors of the Interaction between the E3 Ligase VHL and HIF1\u03b1'}
# DEBUG: Crawled (200) <GET http://onlinelibrary.wiley.com/doi/10.1002/anie.201202544/abstract> (referer: None)
# DEBUG: Crawled (200) <GET http://pubs.acs.org/doi/abs/10.1021/ja209924v> (referer: None) ['partial']
# DEBUG: Scraped from <200 http://onlinelibrary.wiley.com/doi/10.1002/anie.201202544/abstract>
# {'abstract': u'Pieces of the puzzle: The first fragment-based approach was used to target cytochrome\u2005P450 enzymes (CYPs) for drug development (see scheme). The experiments provide new insights into the binding site of the essential Mycobacterium tuberculosis CYP121 enzyme, and resulted in a promising novel lead compound based on fragment merging.',
#  'affiliations': [u'Department of Chemistry, University of Cambridge, Lensfield Road, Cambridge, CB2\u20051EW (UK) http://www-abell.ch.cam.ac.uk/Present address: Shanghai ChemPartner Co. Ltd. Shanghai, 201203 (China)',
#                   u'Department of Biochemistry, University of Cambridge, 80 Tennis Court Road, Cambridge, CB2\u20051GA (UK)',
#                   u'Department of Chemistry, University of Cambridge, Lensfield Road, Cambridge, CB2\u20051EW (UK) http://www-abell.ch.cam.ac.uk/',
#                   u'Manchester Interdisciplinary Biocentre, Faculty of Life Sciences, University of Manchester, 131 Princess Street, Manchester, M1\u20057DN (UK)'],
#  'authors': u'SA Hudson, KJ McLean, S Surade, Y Yang, D Leys, A Ciulli, AW Munro, C Abell',
#  'date': u'13 August 2012',
#  'doi': u'10.1002/anie.201202544',
#  'journal': u'Angewandte Chemie International Edition',
#  'publisher': u'Wiley-Blackwell',
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications',
#  'title': u' Application of Fragment Screening and Merging to the Discovery of Inhibitors of the Mycobacterium tuberculosis Cytochrome P450 CYP121 '}
# DEBUG: Scraped from <200 http://pubs.acs.org/doi/abs/10.1021/ja209924v>
# {'abstract': u'E3 ubiquitin ligases, which bind protein targets, leading to their ubiquitination and subsequent degradation, are attractive drug targets due to their exquisite substrate specificity. However, the development of small-molecule inhibitors has proven extraordinarily challenging as modulation of E3 ligase activities requires the targeting of protein\u2013protein interactions. Using rational design, we have generated the first small molecule targeting the von Hippel\u2013Lindau protein (VHL), the substrate recognition subunit of an E3 ligase, and an important target in cancer, chronic anemia, and ischemia. We have also obtained the crystal structure of VHL bound to our most potent inhibitor, confirming that the compound mimics the binding mode of the transcription factor HIF-1\u03b1, a substrate of VHL. These results have the potential to guide future development of improved lead compounds as therapeutics for the treatment of chronic anemia and ischemia.',
#  'affiliations': [u'\u2020Department\r\nof Chemistry, \xa7Department of Molecular, Cellular & Developmental Biology, and \u2225Department of\r\nPharmacology, Yale University, New Haven, Connecticut 06511, United States',
#                   u'\u2021 Department of Chemistry, University\r\nof Cambridge, Lensfield Road, Cambridge\r\nCB2 1EW, United Kingdom'],
#  'authors': u'DL Buckley, I Van Molle, PC Gareiss, HS Tae, J Michel, DJ Noblin, WL Jorgensen, A Ciulli, CM Crews',
#  'date': u'27 February 2012',
#  'doi': u'10.1021/ja209924v',
#  'journal': u'J. Am. Chem. Soc.',
#  'publisher': u'American Chemical Society (ACS)',
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications',
#  'title': u'Targeting the von Hippel\u2013Lindau E3 Ubiquitin Ligase Using Small Molecules To Disrupt the VHL/HIF-1\u03b1 Interaction'}
# DEBUG: Redirecting (301) to <GET http://www.biochemj.org/content/467/3/365> from <GET http://www.biochemj.org/lookup/doi/10.1042/BJ20141450>
# DEBUG: Crawled (401) <GET http://www.nature.com/nmeth/journal/v8/n10/full/nmeth.1679.html> (referer: None)
# DEBUG: Scraped from <401 http://www.nature.com/nmeth/journal/v8/n10/full/nmeth.1679.html>
# {'doi': u'10.1038/nmeth.1679',
#  'error': {'404': 'publisher'},
#  'source_url': u'http://www.lifesci.dundee.ac.uk/gre/staff/professor-anton-gartner'}
# DEBUG: Redirecting (301) to <GET http://www.biochemj.org/content/473/3/335> from <GET http://www.biochemj.org/lookup/doi/10.1042/BJ20141555>
# DEBUG: Crawled (200) <GET http://www.pnas.org/content/110/32/12984> (referer: None)
# DEBUG: Crawled (200) <GET http://jb.asm.org/content/187/15/5061> (referer: None)
# DEBUG: Scraped from <200 http://www.pnas.org/content/110/32/12984>
# {'abstract': u'In fragment-based drug discovery, the weak affinities exhibited by fragments pose significant challenges for screening. Biophysical                              techniques are used to address this challenge, but there is no clear consensus on which cascade of methods is best suited                              to identify fragment hits that ultimately translate into bound X-ray structures and provide bona fide starting points for                              synthesis. We have benchmarked an integrated biophysical approach for fragment screening and validation against Mycobacterium tuberculosis pantothenate synthetase. A primary screen of 1,250 fragments library was performed by thermal shift, followed by secondary                              screen using one-dimensional NMR spectroscopy (water ligand observed gradient spectroscopy and saturation transfer difference                              binding experiments) and ultimate hit validation by isothermal titration calorimetry and X-ray crystallography. Our multibiophysical                              approach identified three distinct binding sites for fragments and laid a solid foundation for successful structure-based                              elaboration into potent inhibitors.                           ',
#  'affiliations': [],
#  'authors': u'HL Silvestre, TL Blundell, C Abell, A Ciulli',
#  'date': u'19 July 2013',
#  'doi': u'10.1073/pnas.1304045110',
#  'journal': u'Proceedings of the National Academy of Sciences',
#  'publisher': u'Proceedings of the National Academy of Sciences',
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications',
#  'title': u'Integrated biophysical approach to fragment screening and validation for fragment-based lead discovery'}
# DEBUG: Scraped from <200 http://jb.asm.org/content/187/15/5061>
# {'doi': u'10.1128/jb.187.15.5061-5066.2005',
#  'error': {'missing_pub': 'jb.asm.org'},
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications'}
# DEBUG: Crawled (200) <GET http://www.biochemj.org/content/473/3/335> (referer: None)
# DEBUG: Crawled (200) <GET http://www.biochemj.org/content/467/3/365> (referer: None)
# DEBUG: Scraped from <200 http://www.biochemj.org/content/473/3/335>
# {'doi': u'10.1042/bj20141555',
#  'error': {'missing_pub': 'www.biochemj.org'},
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications'}
# DEBUG: Scraped from <200 http://www.biochemj.org/content/467/3/365>
# {'doi': u'10.1042/bj20141450',
#  'error': {'missing_pub': 'www.biochemj.org'},
#  'source_url': u'http://www.lifesci.dundee.ac.uk/groups/alessio-ciulli//publications'}
# INFO: Closing spider (finished)
# INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 332171,
#  'downloader/request_count': 920,
#  'downloader/request_method_count/GET': 920,
#  'downloader/response_bytes': 10341846,
#  'downloader/response_count': 920,
#  'downloader/response_status_count/200': 223,
#  'downloader/response_status_count/301': 219,
#  'downloader/response_status_count/302': 223,
#  'downloader/response_status_count/303': 244,
#  'downloader/response_status_count/401': 11,
#  'dupefilter/filtered': 10,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 3, 18, 14, 40, 35, 320361),
#  'item_scraped_count': 234,
#  'log_count/DEBUG': 1156,
#  'log_count/INFO': 8,
#  'response_received_count': 234,
#  'scheduler/dequeued': 920,
#  'scheduler/dequeued/memory': 920,
#  'scheduler/enqueued': 920,
#  'scheduler/enqueued/memory': 920,
#  'start_time': datetime.datetime(2016, 3, 18, 14, 39, 24, 850847)}
# INFO: Spider closed (finished)

# %% [markdown]
# # Cherry has found us raw documents
# ### Now lets make a corpus from those documents
#
# * Find the `complete.json` file from the scraping run
# * move it to the cwd
# * Continue:

# %%
from fruitbowl.orange import corpus,docIterators 

corp=corpus.Corpus('Example_Corpus',doc_iterator)
# Out:
# Building Dictionary

# %% [markdown]
# ### The corpus has been built
#
# * The corpus is built on gensim
# * Get a random sample of documents via `get_sample` method
#
# ### The corpus has been tokenized - each word has been tokenized into an integer:
#
# * Access the dictionary (token to word) via `corp.dictionary[token]`
# * Access the inverse dictionary (word to token) via `corp.inv_dict[word]`
#
#
# We can to save the corpus to disk so that documents can be accessed later.

# %%
sample = corp.get_sample(1)
sample_document = sample[0]
print(sample_document['doi'])
print('')
print(sample_document['doc'])
print('\n'*2)
print(corp.dictionary[200])
print(corp.inv_dict['Topographic'])


corp.export2jsonfile('_SAVED.json')
# Out:
# Sampling 1 random documents
#
#
# 10.1371/journal.pgen.1001285
#
# [[u'Evolutionary', u'Conserved', u'Regulation', u'of', u'HIF-1\u03b2', u'by', u'NF-\u03baB'], [u'Hypoxia', u'Inducible', u'Factor-1', u'(HIF-1)', u'is', u'essential', u'for', u'mammalian', u'development', u'and', u'is', u'the', u'principal', u'transcription', u'factor', u'activated', u'by', u'low', u'oxygen', u'tensions'], [u'HIF-\u03b1', u'subunit', u'quantities', u'and', u'their', u'associated', u'activity', u'are', u'regulated', u'in', u'a', u'post-translational', u'manner,', u'through', u'the', u'concerted', u'action', u'of', u'a', u'class', u'of', u'enzymes', u'called', u'Prolyl', u'Hydroxylases', u'(PHDs)', u'and', u'Factor', u'Inhibiting', u'HIF', u'(FIH)', u'respectively'], [u'However,', u'alternative', u'modes', u'of', u'HIF-\u03b1', u'regulation', u'such', u'as', u'translation', u'or', u'transcription', u'are', u'under-investigated,', u'and', u'their', u'importance', u'has', u'not', u'been', u'firmly', u'established'], [u'Here,', u'we', u'demonstrate', u'that', u'NF-\u03baB', u'regulates', u'the', u'HIF', u'pathway', u'in', u'a', u'significant', u'and', u'evolutionary', u'conserved', u'manner'], [u'We', u'demonstrate', u'that', u'NF-\u03baB', u'directly', u'regulates', u'HIF-1\u03b2', u'mRNA', u'and', u'protein'], [u'In', u'addition,', u'we', u'found', u'that', u'NF-\u03baB\u2013mediated', u'changes', u'in', u'HIF-1\u03b2', u'result', u'in', u'modulation', u'of', u'HIF-2\u03b1', u'protein'], [u'HIF-1\u03b2', u'overexpression', u'can', u'rescue', u'HIF-2\u03b1', u'protein', u'levels', u'following', u'NF-\u03baB', u'depletion'], [u'Significantly,', u'NF-\u03baB', u'regulates', u'HIF-1\u03b2', u'(tango)', u'and', u'HIF-\u03b1', u'(sima)', u'levels', u'and', u'activity', u'(Hph/fatiga,', u'ImpL3/ldha)', u'in', u'Drosophila,', u'both', u'in', u'normoxia', u'and', u'hypoxia,', u'indicating', u'an', u'evolutionary', u'conserved', u'mode', u'of', u'regulation'], [u'These', u'results', u'reveal', u'a', u'novel', u'mechanism', u'of', u'HIF', u'regulation,', u'with', u'impact', u'in', u'the', u'development', u'of', u'novel', u'therapeutic', u'strategies', u'for', u'HIF\u2013related', u'pathologies', u'including', u'ageing,', u'ischemia,', u'and', u'cancer.']]
#
#
#
# Topographic
# 200
#
#
# EXPORT COMPLETE

# %% [markdown]
# # With a corpus built, lets make some models
# ### First, lets represent a document as its Bag Of Words representation:

# %%
for sentence in sample_document['doc']:
    print(' '.join(sentence))
    print(corp.get_cbow_doc(sentence))
    print('')
# Out:
# Evolutionary Conserved Regulation of HIF-1β by NF-κB
# [(39, 1), (40, 1), (1297, 1), (1936, 1), (1939, 1), (1960, 1), (1982, 1)]
#
# Hypoxia Inducible Factor-1 (HIF-1) is essential for mammalian development and is the principal transcription factor activated by low oxygen tensions
# [(24, 1), (39, 1), (59, 2), (75, 1), (101, 1), (323, 1), (542, 1), (544, 1), (548, 1), (553, 1), (732, 1), (809, 1), (1593, 1), (1937, 1), (1948, 1), (1951, 1), (1953, 1), (1969, 1), (1981, 1)]
#
# HIF-α subunit quantities and their associated activity are regulated in a post-translational manner, through the concerted action of a class of enzymes called Prolyl Hydroxylases (PHDs) and Factor Inhibiting HIF (FIH) respectively
# [(17, 1), (22, 1), (40, 2), (58, 1), (75, 2), (81, 1), (95, 2), (101, 1), (525, 1), (547, 1), (560, 1), (579, 1), (1427, 1), (1528, 1), (1758, 1), (1941, 1), (1944, 1), (1947, 1), (1956, 1), (1957, 1), (1958, 1), (1961, 1), (1966, 1), (1968, 1), (1973, 1), (1976, 1), (1977, 1), (1984, 1), (1985, 1)]
#
# However, alternative modes of HIF-α regulation such as translation or transcription are under-investigated, and their importance has not been firmly established
# [(7, 1), (22, 1), (40, 1), (57, 1), (58, 1), (75, 1), (110, 1), (182, 1), (427, 1), (542, 1), (543, 1), (570, 1), (583, 1), (1220, 1), (1495, 1), (1650, 1), (1940, 1), (1950, 1), (1955, 1), (1972, 1), (1976, 1)]
#
# Here, we demonstrate that NF-κB regulates the HIF pathway in a significant and evolutionary conserved manner
# [(32, 1), (75, 1), (81, 1), (95, 1), (101, 1), (133, 1), (452, 1), (547, 1), (683, 1), (767, 1), (1148, 1), (1256, 1), (1257, 1), (1520, 1), (1936, 1), (1942, 1)]
#
# We demonstrate that NF-κB directly regulates HIF-1β mRNA and protein
# [(3, 1), (75, 1), (133, 1), (683, 1), (870, 1), (914, 1), (1257, 1), (1936, 1), (1943, 1), (1960, 1)]
#
# In addition, we found that NF-κB–mediated changes in HIF-1β result in modulation of HIF-2α protein
# [(32, 1), (40, 1), (81, 2), (91, 1), (133, 1), (591, 1), (784, 1), (851, 1), (914, 1), (1465, 1), (1946, 1), (1960, 1), (1965, 1), (1978, 1)]
#
# HIF-1β overexpression can rescue HIF-2α protein levels following NF-κB depletion
# [(588, 1), (914, 1), (1157, 1), (1936, 1), (1946, 1), (1954, 1), (1960, 1), (1963, 1), (1979, 1), (1980, 1)]
#
# Significantly, NF-κB regulates HIF-1β (tango) and HIF-α (sima) levels and activity (Hph/fatiga, ImpL3/ldha) in Drosophila, both in normoxia and hypoxia, indicating an evolutionary conserved mode of regulation
# [(17, 1), (40, 1), (75, 3), (81, 2), (199, 1), (238, 1), (362, 1), (543, 1), (1157, 1), (1256, 1), (1257, 1), (1520, 1), (1936, 1), (1945, 1), (1949, 1), (1959, 1), (1960, 1), (1962, 1), (1964, 1), (1967, 1), (1970, 1), (1971, 1), (1975, 1), (1976, 1)]
#
# These results reveal a novel mechanism of HIF regulation, with impact in the development of novel therapeutic strategies for HIF–related pathologies including ageing, ischemia, and cancer.
# [(24, 1), (40, 2), (67, 1), (75, 1), (81, 1), (95, 1), (101, 1), (134, 1), (247, 1), (547, 1), (576, 2), (594, 1), (809, 1), (902, 1), (1258, 1), (1319, 1), (1324, 1), (1938, 1), (1952, 1), (1974, 1), (1983, 1), (1986, 1), (1987, 1), (1988, 1)]

# %% [markdown]
# # Next, lets get the tfidf representation:
# Note that word order is *not* preserved

# %%
#create the tfidf model
corp.get_tfidf_model()
#get the tfidf representation:
for sentence in sample_document['doc']:
    print(' '.join(sentence))
    for k,v in corp.get_tfidf_doc(sentence):
        print(corp.dictionary[k],v)
    print('')
# Out:
# Creating TF-IDF Model
# Evolutionary Conserved Regulation of HIF-1β by NF-κB
# (u'by', 0.05997220351073987)
# (u'of', 0.009991079309451001)
# (u'Evolutionary', 0.4438891566014532)
# (u'NF-\u03baB', 0.4438891566014532)
# (u'Regulation', 0.36933851475796803)
# (u'HIF-1\u03b2', 0.5184397984449385)
# (u'Conserved', 0.4438891566014532)
#
# Hypoxia Inducible Factor-1 (HIF-1) is essential for mammalian development and is the principal transcription factor activated by low oxygen tensions
# (u'for', 0.02347092805874262)
# (u'by', 0.040837993317608665)
# (u'is', 0.0736478244483421)
# (u'and', 0.010117943893314192)
# (u'the', 0.010117943893314192)
# (u'oxygen', 0.23515784536060694)
# (u'transcription', 0.165177479792776)
# (u'Hypoxia', 0.2725700229735426)
# (u'factor', 0.17103969941681435)
# (u'Inducible', 0.25150057717856444)
# (u'essential', 0.17103969941681435)
# (u'development', 0.13362752180387866)
# (u'low', 0.1774122949539822)
# (u'activated', 0.3022657389569286)
# (u'principal', 0.3530309007352927)
# (u'(HIF-1)', 0.3530309007352927)
# (u'tensions', 0.3530309007352927)
# (u'Factor-1', 0.3530309007352927)
# (u'mammalian', 0.2725700229735426)
#
# HIF-α subunit quantities and their associated activity are regulated in a post-translational manner, through the concerted action of a class of enzymes called Prolyl Hydroxylases (PHDs) and Factor Inhibiting HIF (FIH) respectively
# (u'activity', 0.10801463139915014)
# (u'are', 0.038292763533102236)
# (u'of', 0.00980018449779848)
# (u'their', 0.06982832487601662)
# (u'and', 0.014574703366301263)
# (u'in', 0.012953708625882342)
# (u'a', 0.02700067948153633)
# (u'the', 0.007287351683150632)
# (u'Factor', 0.18114086950280878)
# (u'HIF', 0.19631593499991462)
# (u'class', 0.18114086950280878)
# (u'enzymes', 0.1516214553705362)
# (u'associated', 0.1277794974825693)
# (u'through', 0.1277794974825693)
# (u'called', 0.21770398855463807)
# (u'regulated', 0.18114086950280878)
# (u'concerted', 0.25426710760646737)
# (u'Prolyl', 0.25426710760646737)
# (u'post-translational', 0.19631593499991462)
# (u'quantities', 0.21770398855463807)
# (u'(FIH)', 0.25426710760646737)
# (u'(PHDs)', 0.25426710760646737)
# (u'respectively', 0.25426710760646737)
# (u'manner,', 0.25426710760646737)
# (u'Hydroxylases', 0.25426710760646737)
# (u'HIF-\u03b1', 0.25426710760646737)
# (u'subunit', 0.15975281594808535)
# (u'action', 0.21770398855463807)
# (u'Inhibiting', 0.25426710760646737)
#
# However, alternative modes of HIF-α regulation such as translation or transcription are under-investigated, and their importance has not been firmly established
# (u'has', 0.10166574000304378)
# (u'are', 0.057038196541046)
# (u'of', 0.007298831397226352)
# (u'been', 0.11977840499461838)
# (u'their', 0.10401134185489744)
# (u'and', 0.010854724475760347)
# (u'such', 0.14738837891820258)
# (u'not', 0.15163653926665013)
# (u'as', 0.059701903389591776)
# (u'transcription', 0.17720557176995397)
# (u'regulation', 0.20609837952607915)
# (u'However,', 0.15612758026247278)
# (u'or', 0.1141637436490208)
# (u'modes', 0.2522818515913648)
# (u'importance', 0.2258446132723776)
# (u'alternative', 0.29241835405753985)
# (u'under-investigated,', 0.37873832858900064)
# (u'established', 0.29241835405753985)
# (u'firmly', 0.37873832858900064)
# (u'translation', 0.29241835405753985)
# (u'HIF-\u03b1', 0.37873832858900064)
#
# Here, we demonstrate that NF-κB regulates the HIF pathway in a significant and evolutionary conserved manner
# (u'we', 0.077525730016051)
# (u'and', 0.013779964411336647)
# (u'in', 0.02449472066405191)
# (u'a', 0.02552836877611877)
# (u'the', 0.013779964411336647)
# (u'that', 0.03650053459154379)
# (u'significant', 0.21756872024788917)
# (u'HIF', 0.3712221826664358)
# (u'demonstrate', 0.24162370698802596)
# (u'Here,', 0.24162370698802596)
# (u'pathway', 0.2867074830259526)
# (u'conserved', 0.26163983631694965)
# (u'regulates', 0.2867074830259526)
# (u'evolutionary', 0.4116657662378586)
# (u'NF-\u03baB', 0.4116657662378586)
# (u'manner', 0.3425270034597952)
#
# We demonstrate that NF-κB directly regulates HIF-1β mRNA and protein
# (u'We', 0.11301829135274379)
# (u'and', 0.015403730629326814)
# (u'that', 0.04080158597594146)
# (u'demonstrate', 0.27009550859514303)
# (u'mRNA', 0.33767950980469597)
# (u'protein', 0.15103152655592775)
# (u'regulates', 0.3204917448343162)
# (u'NF-\u03baB', 0.46017452463277464)
# (u'directly', 0.4149652593239076)
# (u'HIF-1\u03b2', 0.5374602741519864)
#
# In addition, we found that NF-κB–mediated changes in HIF-1β result in modulation of HIF-2α protein
# (u'we', 0.07345395105991222)
# (u'of', 0.008779138895641598)
# (u'in', 0.0464164352276586)
# (u'In', 0.09579442052546289)
# (u'that', 0.03458346643098738)
# (u'changes', 0.20614165291893938)
# (u'addition,', 0.22893323215838693)
# (u'found', 0.20614165291893938)
# (u'protein', 0.12801447796042897)
# (u'result', 0.2862175014140124)
# (u'HIF-2\u03b1', 0.4555518836960016)
# (u'HIF-1\u03b2', 0.4555518836960016)
# (u'modulation', 0.3517249825611269)
# (u'NF-\u03baB\u2013mediated', 0.4555518836960016)
#
# HIF-1β overexpression can rescue HIF-2α protein levels following NF-κB depletion
# (u'can', 0.10983120005801982)
# (u'protein', 0.11497716705000408)
# (u'levels', 0.2056181058310353)
# (u'NF-\u03baB', 0.35032131633302444)
# (u'HIF-2\u03b1', 0.4091573536537795)
# (u'depletion', 0.3159044408093522)
# (u'HIF-1\u03b2', 0.4091573536537795)
# (u'rescue', 0.4091573536537795)
# (u'overexpression', 0.35032131633302444)
# (u'following', 0.29148527901226934)
#
# Significantly, NF-κB regulates HIF-1β (tango) and HIF-α (sima) levels and activity (Hph/fatiga, ImpL3/ldha) in Drosophila, both in normoxia and hypoxia, indicating an evolutionary conserved mode of regulation
# (u'activity', 0.11335677365085273)
# (u'of', 0.005142438952313449)
# (u'and', 0.022943299381593767)
# (u'in', 0.02718873540783654)
# (u'mode', 0.17774681315123977)
# (u'an', 0.04918340092296326)
# (u'both', 0.08647989133053434)
# (u'regulation', 0.14520794867057013)
# (u'levels', 0.13409916217577614)
# (u'conserved', 0.14520794867057013)
# (u'regulates', 0.1591202855985117)
# (u'evolutionary', 0.22847110094077594)
# (u'NF-\u03baB', 0.22847110094077594)
# (u'Significantly,', 0.2668425433707503)
# (u'Drosophila,', 0.2668425433707503)
# (u'indicating', 0.2060252460206602)
# (u'HIF-1\u03b2', 0.2668425433707503)
# (u'(Hph/fatiga,', 0.2668425433707503)
# (u'(tango)', 0.2668425433707503)
# (u'ImpL3/ldha)', 0.2668425433707503)
# (u'(sima)', 0.2668425433707503)
# (u'hypoxia,', 0.2668425433707503)
# (u'normoxia', 0.2668425433707503)
# (u'HIF-\u03b1', 0.2668425433707503)
#
# These results reveal a novel mechanism of HIF regulation, with impact in the development of novel therapeutic strategies for HIF–related pathologies including ageing, ischemia, and cancer.
# (u'for', 0.021518967367912683)
# (u'of', 0.012475212569596172)
# (u'with', 0.04133541393472442)
# (u'and', 0.009276484676092675)
# (u'in', 0.016489512897312878)
# (u'a', 0.017185350751884685)
# (u'the', 0.009276484676092675)
# (u'These', 0.11923823364727267)
# (u'mechanism', 0.14646430419778325)
# (u'HIF', 0.24990172587803053)
# (u'novel', 0.2749959427057072)
# (u'results', 0.11923823364727267)
# (u'development', 0.12251438349416305)
# (u'strategies', 0.24990172587803053)
# (u'including', 0.1334271642780511)
# (u'impact', 0.24990172587803053)
# (u'reveal', 0.19300757922301243)
# (u'regulation,', 0.27712779642854113)
# (u'ageing,', 0.32367107145377033)
# (u'HIF\u2013related', 0.32367107145377033)
# (u'cancer.', 0.27712779642854113)
# (u'ischemia,', 0.32367107145377033)
# (u'pathologies', 0.32367107145377033)
# (u'therapeutic', 0.20335845085280138)

# %% [markdown]
# # Moving on to sanitising:
# ### Before training more powerful algorithms, it is useful to clean the data
#
# The document iterator class has been simply returning the document as scraped from the page.
#
# Sanitiser Objects are designed to improve the data quality of the documents:

# %%
from fruitbowl.strawberry import sanitisers

#get sources:
punctuation = 'fruitbowl/strawberry/ancillaries/punctuation.json'
stopwords = 'fruitbowl/strawberry/ancillaries/full_stopwords.json'

#get sentence:
sample_sentence=' '.join(sample_document['doc'][0])
print('sample sentence:')
print(sample_sentence+'\n')
#define sanitisers:
min_san = sanitisers.MinimalSanitiser(punctuation)
stop_san = sanitisers.StopWordSanitiser(punct_file=punctuation,stopwords_file=stopwords)
stem_san = sanitisers.StemmingSanitiser(punct_file=punctuation,stopwords_file=stopwords,stem_type='SNOWBALL')
#show sanitising:
print('minimal_sanitising:')
print(min_san.sanitise(sample_sentence)+'\n')
print('stopword_sanitising:')
print(stop_san.sanitise(sample_sentence)+'\n')
print('stopword and stemming sanitising:')
print(stem_san.sanitise(sample_sentence)+'\n')
# Out:
# sample sentence:
# Evolutionary Conserved Regulation of HIF-1β by NF-κB
#
# minimal_sanitising:
# evolutionary conserved regulation of hif 1β by nf κb
#
# stopword_sanitising:
# evolutionary conserved regulation hif 1β nf κb
#
# stopword and stemming sanitising:
# evolutionari conserv regul hif 1β nf κb

# %% [markdown]
# # Lets use the stemming sanitiser to stream documents into the corpus
#
# * Give the corpus's document iterator the stemming sanitiser to use in streaming
# * Rebuild the corpus's dictionaries
# * Rebuild the corpus's TFIDF model
# * Save the new corpus to file, including TFIDF weights

# %%
corp.doc_iter.sanitiser=stem_san
corp.rebuild_dicts()
corp.get_tfidf_model()

corp.export2jsonfile('_SAVED2.json',tfidf=True)
# Out:
# Creating TF-IDF Model
#
#
# EXPORT COMPLETE

# %% [markdown]
# # With properly sanitised input, we can now train word2vec and doc2vec models

# %%
from fruitbowl.strawberry import model_training
print('Training Word2Vec model:')
w2vmodel = model_training.train_word2vec(corp.doc_iter)
print('Training Doc2Vec model:')
d2vmodel = model_training.train_doc2vec(corp.doc_iter)
# Out:
# Training Word2Vec model:
#
#
#
#
# Model Trained
# Training Doc2Vec model:
#
#
# training epoch: 0
#
#
# training epoch: 1
#
#
# training epoch: 2
#
#
# training epoch: 3
#
#
# training epoch: 4
#
#
# training epoch: 5
#
#
# training epoch: 6
#
#
# training epoch: 7
#
#
# training epoch: 8
#
#
# training epoch: 9
#
#
# training epoch: 10
#
#
# training epoch: 11
#
#
# training epoch: 12
#
#
# training epoch: 13
#
#
# training epoch: 14
#
#
# training epoch: 15
#
#
# training epoch: 16
#
#
# training epoch: 17
#
#
# training epoch: 18
#
#
# training epoch: 19
#
#
# training epoch: 20
#
#
# training epoch: 21
#
#
# training epoch: 22
#
#
# training epoch: 23
#
#
# Model Trained

# %% [markdown]
# # Finally we can generate vectors for documents:
# ### 3 Classes are implemented to help facilitate this:
# * `SentBySentGenerator` generates document vectors by averaging word vectors into sentences, then averaging sentence vectors into document vectors
# * `WordByWordGenerator` generates document vectors by averaging word vectors directly into documents
# * `Doc2VecGenerator` generates document vectors using trained doc2vec models

# %%
from  fruitbowl.strawberry import vect_generators
sbs = vect_generators.SentBySentGenerator(w2vmodel)
wbw = vect_generators.WordByWordGenerator(w2vmodel)
d2v = vect_generators.Doc2VecGenerator(d2vmodel)

# %%
sbs_vector = sbs.get_vector(sample_document['doc'])
wbw_vector = wbw.get_vector(sample_document['doc'])
d2v_vector = d2v.get_vector(sample_document['doi'])

# %% [markdown]
# # We have gone from raw scraping  document representation vectors in 15 lines of code
#
# Minimal working example below:

# %%
# %%sh
# cd fruitbowl/cherry/
# sh cherrymaster.sh -p ../../scrape_me2.json
# mv complete.json ../../

# %%
from fruitbowl.orange import corpus,docIterators 
from fruitbowl.strawberry import sanitisers
from fruitbowl.strawberry import model_training

stem_san = sanitisers.StemmingSanitiser(punct_file=punctuation,stopwords_file=stopwords,stem_type='SNOWBALL')
doc_iterator = docIterators.JsonDiskIter('complete.json',sanit=stem_san)
corp=corpus.Corpus('Example_Corpus',doc_iterator)
corp.get_tfidf_model()
corp.export2jsonfile('_SAVED2.json',tfidf=True)
d2v = vect_generators.Doc2VecGenerator(d2vmodel)
sample_document=corp.get_sample(1)
d2v_vector = d2v.get_vector(sample_document['doi'])
